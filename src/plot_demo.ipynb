# %%
using Plots

# %%
x = collect(0:0.1:2*pi);

# %%
y = sin.(x);

# %%
plot(x,y)

# %%
plot(x,y, color = :red, title="first example")

# %%
plot(x,y, linestyle = :dot, arrow = :arrow, linealpha = 0.5, linewidth = 4, linecolor = :red)

# %%
plot(x, y, markershape = :hexagon,
    markersize = 4,
    markeralpha = 0.6,
    markercolor = :green,
    markerstrokewidth = 2,
    markerstrokealpha = 0.2,
    markerstrokecolor = :red,
    markerstrokestyle = :dot)
# Out:
# ┌ Warning: markershape hexagon is unsupported with Plots.PGFPlotsXBackend().  Choose from: Any[:none, :auto, :circle, :rect, :diamond, :utriangle, :dtriangle, :ltriangle, :rtriangle, :cross, :xcross, :x, :star5, :pentagon, :hline, :vline, Shape]
# └ @ Plots /Users/hailongguo/.julia/packages/Plots/YVapH/src/args.jl:1248

# %%
plot(x,y, 
    xlabel = "my label",
    xlims = (0,2*pi),
    xticks = 0:0.5:2*pi,
    xflip = true,
    xtickfont = font(4, "Courier")
)

# %%
n = collect(1:10);

# %%
y = 0.2.^n;

# %%
pgfplotsx();

# %%
pl = plot(plot(n, y), plot(n, y, xaxis=:log),plot(n,y, yaxis=:log), plot(n,y, xaxis=:log, yaxis=:log), layout = (2, 2))

# %%
savefig(pl,  "myline.tikz")    # produces a tikzpicture environment that can be included in other documents
savefig(pl, "myparabola.tex")
